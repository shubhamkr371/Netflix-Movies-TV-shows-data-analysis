# %% [markdown]
# Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# Load the Dataset

# %%
netflix=pd.read_csv('/content/netflix_titles.csv')

# %%
netflix.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
netflix.shape
# Out:
# (8807, 12)

# %%
netflix.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
netflix.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
netflix.nunique()
# Out:
# show_id         8807
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %%
netflix.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = netflix.copy()

# %%
df.shape
# Out:
# (8807, 12)

# %%
df=df.dropna()
df.shape
# Out:
# (5332, 12)

# %%
df.head(10)
# Out:
#    show_id     type                          title             director  \
# 7       s8    Movie                        Sankofa         Haile Gerima
# 8       s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9      s10    Movie                   The Starling       Theodore Melfi
# 12     s13    Movie                   Je Suis Karl  Christian Schwochow
# 24     s25    Movie                          Jeans           S. Shankar
# 27     s28    Movie                      Grown Ups         Dennis Dugan
# 28     s29    Movie                     Dark Skies        Scott Stewart
# 29     s30    Movie                       Paranoia       Robert Luketic
# 38     s39    Movie            Birth of the Dragon         George Nolfi
# 41     s42    Movie                           Jaws     Steven Spielberg
#
#                                                  cast  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...

# %%
df["date_added"] = pd.to_datetime(df['date_added'], format='%B %d, %Y', errors='coerce')
df['day_added'] = df['date_added'].dt.day
df['year_added'] = df['date_added'].dt.year
df['month_added'] = df['date_added'].dt.month
df['year_added'] = pd.to_numeric(df['year_added'], errors='coerce').astype('Int64')
df['day_added'] = pd.to_numeric(df['day_added'], errors='coerce').astype('Int64')
df['date_added'] = pd.to_datetime(df['date_added'].dt.strftime('%Y-%m-%d'))

# %%
df.head(10)
# Out:
#    show_id     type                          title             director  \
# 7       s8    Movie                        Sankofa         Haile Gerima
# 8       s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9      s10    Movie                   The Starling       Theodore Melfi
# 12     s13    Movie                   Je Suis Karl  Christian Schwochow
# 24     s25    Movie                          Jeans           S. Shankar
# 27     s28    Movie                      Grown Ups         Dennis Dugan
# 28     s29    Movie                     Dark Skies        Scott Stewart
# 29     s30    Movie                       Paranoia       Robert Luketic
# 38     s39    Movie            Birth of the Dragon         George Nolfi
# 41     s42    Movie                           Jaws     Steven Spielberg
#
#                                                  cast  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='type', data=netflix, palette="Set2")
plt.title('Movie & TV Show Types on Netflix')
plt.show()
# Out:
# <ipython-input-67-35cd30039b14>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='type', data=netflix, palette="Set2")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x='rating', data=netflix, palette="Set2")

plt.xticks(rotation=90, ha='right')

plt.title('Rating of Shows and Movies on Netflix')
plt.gcf().set_size_inches(10, 6)

plt.show()
# Out:
# <ipython-input-76-8a13df905c96>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='rating', data=netflix, palette="Set2")

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='rating',hue='type',data=netflix)
plt.title('Relation between Type and Rating')
plt.show()

# %%
labels = ['Movie', 'TV show']
size = netflix['type'].value_counts()
colors = plt.cm.Wistia(np.linspace(0, 1, 2))
explode = [0, 0.1]
plt.rcParams['figure.figsize'] = (9, 6)
plt.pie(size,labels=labels, colors = colors, explode = explode, shadow = True, startangle = 90)
plt.title('Distribution of Type', fontsize = 25)
plt.legend()
plt.show()

# %%
netflix['rating'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,figsize=(9,6))
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df = netflix.copy()
df = df.dropna()
df["date_added"] = pd.to_datetime(df['date_added'], format='%B %d, %Y', errors='coerce')
df['year_added'] = df['date_added'].dt.year

plt.figure(figsize=(10, 6))
sns.countplot(x='year_added', data=df)
plt.title('Number of Movies/Shows Added per Year')
plt.xlabel('Year Added')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.title('Correlation Heatmap')
numeric_df = df.apply(pd.to_numeric, errors='coerce')
numeric_df = numeric_df.dropna(axis=1, how='all')
sns.heatmap(numeric_df.corr(), annot=True);

# %%
from wordcloud import WordCloud

# %%
plt.subplots(figsize=(10,8))
wordcloud = WordCloud(
                          background_color='white',
                          width=1920,
                          height=1080
                         ).generate(" ".join(df.country))
plt.imshow(wordcloud)
plt.axis('off')
plt.title("Country Names", fontsize=50)
plt.savefig('country.png')
plt.show()

# %%
plt.subplots(figsize=(10,8))
wordcloud = WordCloud(
                          background_color='white',
                          width=1920,
                          height=1080
                         ).generate(" ".join(df.cast))
plt.imshow(wordcloud)
plt.axis('off')

plt.title("Cast Names", fontsize=50)

plt.savefig('cast.png')
plt.show()
